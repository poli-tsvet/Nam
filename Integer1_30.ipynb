# %%
#integer1
L = int(input("Ввидите значение L: "))
total = L//100
print(total)

# %%
#integer2
M = int(input('Ввидите значение M: '))
total = M//1000
print(total)

# %%
#integer3
B = int(input('Ввидите значение B: '))
total = B//1024
print(total)

# %%
#integer4
A = int(input('Ввидите значение A: '))
B = int(input('Ввидите значение B: '))
total = A//B
print(total)

# %%
#integer5
A = int(input('Ввидите значение A: '))
B = int(input('Ввидите значение B: '))
total = A%B
print(total)

# %%
#integer6
A = int(input('Ввидите значение A: '))
T= A//10
S= A%10
print('Десятки: ', T, 'Еденецы: ', S)

# %%
#integer7
num = int(input('Введите двухзначное число: '))
a = num//10
b = num % 10
sum = a + b
pr = a * b
print('Сумма: ', sum)
print('Произведение: ', pr)

# %%
#integer8
num = int(input('Введите двухзначное число: '))
a = num//10
b = num % 10
new_num = b * 10 + a
print('Новое число: ',new_num)
# Out:
# Введите двухзначное число: 98
# Новое число:  89

# %%
#integer9
num = int(input('Введите трёх значное число: '))
a = num//100
print(a)
# Out:
# Введите трёх значное число: 389
# 3

# %%
#integer10
num = int(input('Введите трёх значное число: '))
a = num % 10
c = (num // 10) % 10
print('Еденицы: ', a)
print('Десятки: ', c)
# Out:
# Введите трёх значное число: 345
# Еденицы:  5
# Десятки:  4

# %%
#integer11
num = int(input('Введите трёх значное число: '))
a = num // 100
b = (num // 10) % 10
c = num % 10
sum = a + b + c
pr = a * b * c
print('Сумма: ', sum)
print('Произведение: ', pr)
# Out:
# Введите трёх значное число: 675
# Сумма:  18
# Произведение:  210

# %%
#integer12
num = int(input('Введите трёх значное число: '))
a = num // 100
b = (num // 10) % 10
c = num % 10
new_num = c * 100 + b * 10 + a
print('Новое число: ', new_num)
# Out:
# Введите трёх значное число: 523
# Новое число:  325

# %%
#integer13
num = int(input('Введите трёх значное число: '))
a = num // 100
b = (num // 10) % 10
c = num % 10
new_num = b * 100 + c * 10 + a
print('Новое число: ', new_num)
# Out:
# Введите трёх значное число: 523
# Новое число:  235

# %%
#integer14
num = int(input('Введите трёх значное число: '))
a = num // 100
b = (num // 10) % 10
c = num % 10
new_num = c * 100 + a * 10 + b
print('Новое число: ', new_num)
# Out:
# Введите трёх значное число: 523
# Новое число:  352

# %%
#integer15
num = int(input('Введите трёх значное число: '))
a = num // 100
b = (num // 10) % 10
c = num % 10
new_num = b * 100 + a * 10 + c
print('Новое число: ', new_num)
# Out:
# Введите трёх значное число: 523
# Новое число:  253

# %%
#integer16
num = int(input('Введите трёх значное число: '))
a = num // 100
b = (num // 10) % 10
c = num % 10
new_num = a * 100 + c * 10 + b
print('Новое число: ', new_num)
# Out:
# Введите трёх значное число: 523
# Новое число:  532

# %%
#integer17
num = int(input('Введите число(num>999): '))
a = (num // 100) % 10
print('Сотни: ',a)
# Out:
# Введите число(num>999): 1209
# Сотни:  2

# %%
#integer18
num = int(input('Введите число(num>999): '))
a = (num // 1000) % 10
print('Сотни: ',a)
# Out:
# Введите число(num>999): 1209
# Сотни:  1

# %%
#integer19
n = int(input('Введите число: '))
min = n//60
print('Минуты: ', min)
# Out:
# Введите число: 234
# Минуты:  3

# %%
#integer20
n = int(input('Введите число: '))
hour = n//3600
print('Полных часов: ', hour)

# %%
#integer21
n = int(input('Введите число: '))
sec = n % 60
print('Секунды: ', sec)

# %%
#integer22
n = int(input('Введите число: '))
sec = n % 3600
print('Сукунды: ', sec)

# %%
#integer23
n = int(input('Введите число: '))
min = (n % 3600) // 60
print('Полных минут: ', min)

# %%
#integer24
k = int(input('Введите номер дня в году(1 - 365): '))
den_nedeli = (k - 1) % 7
print('Номер дня недели: ', den_nedeli)

# %%
#integer25
k = int(input('Введите номер дня в году(1 - 365): '))
den_nedeli = (k + 3) % 7
print('Номер дня недели: ', den_nedeli)

# %%
#integer26
k = int(input('Введите номер дня в году(1 - 365): '))
den_nedeli = (k % 7) - 1
print('Номер дня недели: ', den_nedeli)
# Out:
# Введите номер дня в году(1 - 365): 258
# Номер дня недели:  5

# %%
#integer27
k = int(input('Введите номер дня в году(1 - 365): '))
den_nedeli = ((k + 4) % 7) + 1
print('Номер дня недели: ', den_nedeli)

# %%
#integer28
k = int(input('Введите номер дня в году(1 - 365): '))
n = int(input('Введите номер дня недели: '))
den_nedeli = ((k + n - 2) % 7) + 1
print('Номер дня недели: ', den_nedeli)

# %%
#integer29
A = int(input('Введите число: '))
B = int(input('Введите число: '))
C = int(input('Введите число: '))

num1 = A//C
num2 = B//C
F = num1 * num2

S1 = A*B
S2 = F * (C * C)
ostatok = S1 - S2

print('Количество квадратов: ', F)
print('Площадь не занятой части: ', ostatok)

# %%
#integer30
num = int(input('Введите число: '))
a = num//1000
b = (num//100) % 10
stoletie = (a *10 + b) + 1
print('Номер столетия: ',stoletie)
# Out:
# Введите число: 1845
# Номер столетия:  19
